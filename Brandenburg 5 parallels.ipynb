# %%
from music21 import *

# %%
score = converter.parse('http://www.gutenberg.org/files/5190/5190-x/JSB_BWV1050_1.xml')

# %%
score.show()

# %%
from music21.figuredBass import checker

# %%
functionToApply = checker.parallelFifths

# %%
checker.checkConsecutivePossibilities(score, functionToApply, debug=True)
# Out:
# Function To Apply: parallelFifths
# (Offset A, End Time A):  (Offset B, End Time B):  Part Numbers:
# (103.75, 104.0)          (104.0, 104.25)          (4, 5)
# (103.75, 104.0)          (104.0, 104.25)          (4, 8)
# (186.375, 186.5)         (186.5, 186.625)         (2, 7)
# (188.375, 188.5)         (188.5, 188.625)         (2, 7)
# (190.375, 190.5)         (190.5, 190.625)         (2, 7)
# (194.375, 194.5)         (194.5, 194.625)         (1, 7)
# (221.75, 222.0)          (222.0, 222.25)          (4, 5)
# (221.75, 222.0)          (222.0, 222.25)          (4, 8)
# (229.25, 229.5)          (229.5, 229.75)          (7, 8)
# (298.75, 299.0)          (299.0, 299.25)          (1, 5)
# (298.75, 299.0)          (299.0, 299.25)          (1, 8)
# (301.5, 301.75)          (301.75, 302.0)          (2, 7)
# (303.5, 303.75)          (303.75, 304.0)          (2, 7)
# (313.5, 313.75)          (313.75, 314.0)          (1, 7)
# (315.5, 315.75)          (315.75, 316.0)          (1, 7)
# ...

# %%
score.measures(47,48).show()

# %%
score.measures(48,49).show()

# %%
score.measures(49,50).show()

# %%
us = environment.UserSettings()

# %%
us['musicxmlPath'] = '/Applications/Dorico 3.app'

# %%
score.measures(75,76).show()
